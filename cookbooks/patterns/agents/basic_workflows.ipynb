# %% [markdown]
# ## Basic Multi-LLM Workflows
#
# This notebook demonstrates three simple multi-LLM workflows. They trade off cost or latency for potentially improved task performances:
#
# 1. **Prompt-Chaining**: Decomposes a task into sequential subtasks, where each step builds on previous results
# 2. **Parallelization**: Distributes independent subtasks across multiple LLMs for concurrent processing
# 3. **Routing**: Dynamically selects specialized LLM paths based on input characteristics
#
# Note: These are sample implementations meant to demonstrate core concepts - not production code.

# %%
from concurrent.futures import ThreadPoolExecutor
from typing import List, Dict, Callable
from util import llm_call, extract_xml

# %%
def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result

def parallel(prompt: str, inputs: List[str], n_workers: int = 3) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]

def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()
    
    route_response = llm_call(selector_prompt)
    reasoning = extract_xml(route_response, 'reasoning')
    route_key = extract_xml(route_response, 'selection').strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %% [markdown]
# ## Example Usage
#
# Below are practical examples demonstrating each workflow:
# 1. Chain workflow for structured data extraction and formatting
# 2. Parallelization workflow for stakeholder impact analysis
# 3. Route workflow for customer support ticket handling

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 44
#      42 print("\nInput text:")
#      43 print(report)
# ---> 44 formatted_result = chain(report, data_processing_steps)
#      45 print(formatted_result)
#
# Cell In[7], line 6, in chain(input, prompts)
#       4 for i, prompt in enumerate(prompts, 1):
#       5     print(f"\nStep {i}:")
# ----> 6     result = llm_call(f"{prompt}\nInput: {result}")
#       7     print(result)
#       8 return result
#
# File ~/code/anthropic/anthropic-cookbook/patterns/agents/util_bedrock.py:57, in llm_call(prompt, system_prompt, model)
#      52 if system_prompt and system_prompt.strip():
#      53     converse_params["system"] = [{"content": system_prompt}]
# ---> 57 response = client.converse(**converse_params)
#      58     # Extract the assistant's response from the output message
#      59 output_message = response['output']['message']
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ClientError: An error occurred (ExpiredTokenException) when calling the Converse operation: The security token included in the request is expired

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# Market Impact Analysis: Customers
#
# MARKET DYNAMICS
# 1. Rising Technology Costs
# 2. Increasing Environmental Regulations
# 3. Growing Price Competition
# 4. Accelerating Tech Innovation
#
# SPECIFIC CUSTOMER IMPACTS
#
# Price Sensitivity:
# - Higher product costs due to tech advancements
# - Reduced purchasing power
# - Increased demand for value propositions
#
# Priority Recommendations:
# 1. Develop tiered pricing strategies
# 2. Create flexible payment options
# 3. Offer entry-level product lines
# 4. Implement transparent pricing models
#
# Technology Expectations:
# - Demand for cutting-edge features
# - Shorter product lifecycle expectations
# - Increased digital integration requirements
#
# Priority Recommendations:
# 1. Invest in continuous R&D
# 2. Modular product design
# 3. Regular software/firmware updates
# 4. Clear technology roadmap communication
#
# Environmental Concerns:
# - Preference for sustainable products
# - Willingness to pay premium for eco-friendly options
# - Increased scrutiny of corporate environmental practices
#
# Priority Recommendations:
# 1. Develop green product lines
# 2. Transparent sustainability reporting
# 3. Implement circular economy principles
# 4. Carbon footprint reduction strategies
#
# STRATEGIC ACTION PLAN
# High Priority: Price-Value Alignment
# Medium Priority: Technology Innovation
# Low Priority: Incremental Sustainability Improvements
#
# Monitoring Metrics:
# - Customer satisfaction scores
# - Price elasticity
# - Technology adoption rates
# - Sustainability perception index
# Market Changes Impact Analysis: Employees
#
# PRIORITY IMPACTS:
# 1. Job Security Risks (High Concern)
# - Potential role elimination due to market shifts
# - Increased competition for remaining positions
# - Potential salary/compensation pressure
#
# 2. Skill Obsolescence (Critical)
# - Existing skills may become less relevant
# - Technology/automation transforming job requirements
# - Need for rapid upskilling and reskilling
#
# 3. Organizational Uncertainty (Psychological Impact)
# - Reduced employee morale
# - Increased stress and anxiety
# - Potential decreased productivity
#
# RECOMMENDED ACTIONS:
#
# Immediate Actions:
# - Conduct comprehensive skills assessment
# - Develop clear communication plan about company direction
# - Create internal reskilling/training programs
# - Offer career transition support
#
# Medium-Term Strategies:
# - Implement flexible work arrangements
# - Develop cross-functional training opportunities
# - Create internal mobility pathways
# - Provide mental health/wellness resources
#
# Long-Term Investments:
# - Build continuous learning culture
# - Develop adaptive workforce strategy
# - Invest in employee development technologies
# - Create transparent career progression frameworks
#
# PRIORITY RANKING:
# 1. Communication & Transparency
# 2. Skills Development
# 3. Career Path Visibility
# 4. Psychological Support
#
# Estimated Implementation Timeline:
# - Immediate: 0-3 months
# - Short-term: 3-6 months
# - Medium-term: 6-12 months
# - Long-term: 12-24 months
# Market Impact Analysis: Investors
#
# CURRENT CONTEXT
# - Investors seeking stable returns in uncertain economic environment
# - Heightened sensitivity to risk and operational efficiency
# - Increasing demand for transparent, strategic growth plans
#
# POTENTIAL MARKET IMPACTS
#
# High Priority Impacts:
# 1. Investment Risk Perception
# - Potential market volatility may increase risk aversion
# - Reduced tolerance for speculative investments
# - Preference for companies with clear risk mitigation strategies
#
# 2. Growth Expectations
# - Slower economic growth may compress traditional growth metrics
# - Increased scrutiny of revenue and profitability projections
# - Demand for innovative business models and scalability
#
# 3. Cost Management Pressures
# - Heightened focus on operational efficiency
# - Expectations of lean operations and strategic cost control
# - Preference for companies demonstrating disciplined financial management
#
# RECOMMENDED ACTIONS
#
# Strategic Priorities:
# 1. Risk Mitigation
# - Develop comprehensive risk assessment framework
# - Provide transparent reporting on potential challenges
# - Implement robust governance and compliance mechanisms
#
# 2. Growth Communication
# - Articulate clear, realistic growth strategies
# - Demonstrate adaptability and market responsiveness
# - Highlight competitive advantages and innovation potential
#
# 3. Financial Discipline
# - Optimize cost structures
# - Invest in productivity-enhancing technologies
# - Maintain strong balance sheet and cash flow management
#
# IMPLEMENTATION ROADMAP
# - Quarterly investor communications
# - Regular performance benchmarking
# - Proactive risk and opportunity disclosure
#
# Potential Outcomes:
# - Increased investor confidence
# - Improved capital access
# - Enhanced market valuation
# Market Impact Analysis: Suppliers
#
# EXECUTIVE SUMMARY
# Market dynamics are creating significant challenges and opportunities for suppliers, requiring strategic adaptation and proactive management.
#
# CRITICAL MARKET IMPACTS
#
# 1. Capacity Constraints
#    High Priority Impacts:
#    - Potential production bottlenecks
#    - Reduced flexibility in supply chain
#    - Increased operational stress
#
#    Recommended Actions:
#    - Invest in production scalability
#    - Develop alternative manufacturing capabilities
#    - Implement flexible workforce strategies
#
# 2. Price Pressures
#    Medium Priority Impacts:
#    - Margin compression
#    - Potential cost-cutting requirements
#    - Competitive pricing challenges
#
#    Recommended Actions:
#    - Optimize operational efficiency
#    - Explore value-added service offerings
#    - Negotiate long-term contracts with favorable terms
#
# 3. Technology Transitions
#    High Priority Impacts:
#    - Required technology investments
#    - Potential obsolescence risks
#    - Need for continuous skill upgrades
#
#    Recommended Actions:
#    - Develop technology roadmap
#    - Invest in workforce training
#    - Establish strategic technology partnerships
#
# STRATEGIC PRIORITIES
# 1. Operational Resilience
# 2. Technology Adaptation
# 3. Cost Management
#
# RISK MITIGATION
# - Diversify supply chain
# - Maintain financial flexibility
# - Continuously monitor market trends
#
# CONCLUSION
# Proactive, strategic responses will be critical for supplier survival and growth in evolving market conditions.

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The key indicators in this ticket point to an account access issue:
# - User explicitly states they "can't access my account"
# - Experiencing login problems with password
# - Indicates urgency due to needing to submit a report
# - Problem seems to be related to authentication/login credentials
#
# This suggests the issue is not about billing, product features, or technical infrastructure, but specifically about account access and login capabilities. The account support team is best equipped to help with password resets, account verification, and login troubleshooting.
#
#
# Selected route: account
# Account Support Response:
#
# Dear John,
#
# We take account access issues seriously and will assist you immediately with account recovery. Based on the information provided, we recommend the following secure steps:
#
# Verification Process:
# 1. Attempt password reset through official channels:
#    - Use the "Forgot Password" link on our login page
#    - Verify your identity via registered email or phone number
#    - Do NOT share your current password with any support representative
#
# Potential Access Barriers:
# - Confirm you're using the correct username
# - Check for any caps lock or keyboard layout issues
# - Verify you're on the official login page (not a phishing site)
#
# Urgent Recovery Options:
# - If password reset fails, contact our support team directly
# - Provide:
#   * Username
#   * Registered email address
#   * Date of last successful login
#
# Security Warning:
# - Multiple failed login attempts may trigger temporary account lockout
# - Never reuse passwords across multiple platforms
# - Consider enabling two-factor authentication for enhanced security
#
# Expected Resolution Time:
# - Initial response within 2 business hours
# - Full account access restoration within 24-48 hours
#
# Recommended Immediate Action:
# Do not attempt repeated logins, as this may further compromise account security.
#
# Securely,
# Account Security Team
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This input clearly relates to a billing issue. The customer is questioning a charge that seems different from what they expected. The specific concerns are:
# - Unexpected charge amount ($49.99 vs expected $29.99)
# - Potential billing error
# - Need for charge explanation and possible adjustment
#
# The language indicates the customer wants financial clarification, which is a classic billing department responsibility. This is not a technical problem with the service, an account access issue, or a product feature question. The billing team is best equipped to review the charge, explain the discrepancy, and make any necessary corrections.
#
#
# Selected route: billing
# Billing Support Response:
#
# Hello Sarah,
#
# Thank you for bringing the discrepancy in your billing to our attention regarding the $49.99 charge versus your expected $29.99 plan rate.
#
# After reviewing your account, I can confirm there appears to be a potential billing error. Our records will be checked within the next 24-48 hours to verify the correct pricing tier for your account.
#
# Next steps:
# 1. We will conduct a full billing review by [specific date/2 business days]
# 2. If an overcharge is confirmed, we will:
#    - Refund the price difference
#    - Adjust your account to the correct $29.99 plan
#    - Issue a credit to your original payment method
#
# Payment options for any outstanding balance:
# - Credit card on file
# - Online payment portal
# - Phone payment with our billing team
#
# We apologize for any inconvenience and appreciate you bringing this to our attention. A detailed explanation will be emailed to you within 2 business days.
#
# Please let me know if you have any additional questions.
#
# Best regards,
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This ticket is clearly a technical support request related to a specific product feature (data export functionality). The user is experiencing difficulty understanding how to perform a bulk export of project data and is seeking step-by-step guidance. The language suggests the user has already attempted to resolve the issue independently by checking documentation, which indicates this is a legitimate technical support need. The query is about system functionality and requires technical expertise to explain the export process, making the technical support team the most appropriate team to handle this request.
#
#
# Selected route: technical
# Technical Support Response:
#
# Data Export Procedure for Project Management System:
#
# System Requirements:
# - Microsoft Excel 2013 or newer
# - Latest version of project management software
# - Admin or export-enabled user permissions
#
# Export Steps:
# 1. Log into project management system
# 2. Navigate to "Reports" or "Export" section
# 3. Select "Bulk Export" option
# 4. Choose export format: .xlsx (Excel)
# 5. Select project scope:
#    - All projects
#    - Specific project range
#    - Date-based filter
# 6. Click "Generate Export"
# 7. Save exported file to designated location
#
# Troubleshooting Workarounds:
# - If export button is disabled, verify user permissions
# - Large datasets might require multiple export attempts
# - Use browser's download manager for interrupted exports
# - Clear browser cache if experiencing export errors
#
# Common Issues:
# - Ensure stable internet connection
# - Check file size limitations
# - Verify Excel compatibility
#
# Escalation Path:
# If export fails after following these steps:
# 1. Screenshot export error
# 2. Contact support@companydomain.com
# 3. Include:
#    - Software version
#    - Export parameters
#    - Error message details
#
# Need further assistance? Reply with specific error messages or screenshots.
